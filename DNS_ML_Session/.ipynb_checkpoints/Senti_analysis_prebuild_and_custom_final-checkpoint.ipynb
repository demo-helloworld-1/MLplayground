# %% [markdown]
# <a href="https://colab.research.google.com/github/demo-helloworld-1/MLplayground/blob/main/Sentianalysiswithcsv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk textblob
# Out:
# Requirement already satisfied: nltk in c:\users\dhanu\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: textblob in c:\users\dhanu\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: click in c:\users\dhanu\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\dhanu\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dhanu\anaconda3\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\dhanu\anaconda3\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\users\dhanu\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
from textblob import TextBlob

# %% [markdown]
# punkt helps with tokenization—breaking your text into individual words or sentences—while vader_lexicon is great for sentiment analysis using the VADER (Valence Aware Dictionary and sEntiment Reasoner) tool.

# %%
nltk.download('punkt')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dhanu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\dhanu\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
def analyze_sentiment(text):
    analysis = TextBlob(text)
    # Classify sentiment as positive, negative, or neutral
    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'negative'
# Example usage:
text = "I need to buy this product again and again, but this product could be much better"
sentiment = analyze_sentiment(text)
print(f"Sentiment: {sentiment}")
# Out:
# Sentiment: positive

# %%
import nltk
from textblob import TextBlob


def analyze_sentiment(text):
    analysis = TextBlob(text)
    # Calculate sentiment percentages
    positive_percentage = (analysis.sentiment.polarity + 1) / 2 * 100
    negative_percentage = (1 - analysis.sentiment.polarity) / 2 * 100

    # Classify sentiment based on percentages
    if positive_percentage > negative_percentage:
        sentiment = 'positive'
    elif positive_percentage < negative_percentage:
        sentiment = 'negative'
    else:
        sentiment = 'neutral'

    # Return sentiment and percentages
    return sentiment, positive_percentage, negative_percentage

# Example usage
text = "Goutham has too many problems, but he is capable of handling it"
sentiment, positive_percentage, negative_percentage = analyze_sentiment(text)

print(f"Sentiment: {sentiment}")
print(f"Positive Percentage: {positive_percentage:.2f}%")
print(f"Negative Percentage: {negative_percentage:.2f}%")
# Out:
# Sentiment: positive
# Positive Percentage: 67.50%
# Negative Percentage: 32.50%

# %%
pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in c:\users\dhanu\anaconda3\lib\site-packages (0.3.7)
# Requirement already satisfied: model-signing in c:\users\dhanu\anaconda3\lib\site-packages (from kagglehub) (0.2.0)
# Requirement already satisfied: packaging in c:\users\dhanu\anaconda3\lib\site-packages (from kagglehub) (23.2)
# Requirement already satisfied: requests in c:\users\dhanu\anaconda3\lib\site-packages (from kagglehub) (2.32.2)
# Requirement already satisfied: tqdm in c:\users\dhanu\anaconda3\lib\site-packages (from kagglehub) (4.66.4)
# Requirement already satisfied: cryptography in c:\users\dhanu\anaconda3\lib\site-packages (from model-signing->kagglehub) (44.0.0)
# Requirement already satisfied: in-toto-attestation in c:\users\dhanu\anaconda3\lib\site-packages (from model-signing->kagglehub) (0.9.3)
# Requirement already satisfied: sigstore in c:\users\dhanu\anaconda3\lib\site-packages (from model-signing->kagglehub) (3.6.1)
# Requirement already satisfied: typing-extensions in c:\users\dhanu\anaconda3\lib\site-packages (from model-signing->kagglehub) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dhanu\anaconda3\lib\site-packages (from requests->kagglehub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dhanu\anaconda3\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dhanu\anaconda3\lib\site-packages (from requests->kagglehub) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dhanu\anaconda3\lib\site-packages (from requests->kagglehub) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\dhanu\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in c:\users\dhanu\anaconda3\lib\site-packages (from cryptography->model-signing->kagglehub) (1.16.0)
# Requirement already satisfied: protobuf in c:\users\dhanu\anaconda3\lib\site-packages (from in-toto-attestation->model-signing->kagglehub) (3.20.3)
# Requirement already satisfied: id>=1.1.0 in c:\users\dhanu\anaconda3\lib\site-packages (from sigstore->model-signing->kagglehub) (1.5.0)
# Requirement already satisfied: pyasn1~=0.6 in c:\users\dhanu\anaconda3\lib\site-packages (from sigstore->model-signing->kagglehub) (0.6.1)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\dhanu\anaconda3\lib\site-packages (from sigstore->model-signing->kagglehub) (2.5.3)
# Requirement already satisfied: pyjwt>=2.1 in c:\users\dhanu\anaconda3\lib\site-packages (from sigstore->model-signing->kagglehub) (2.8.0)
# Requirement already satisfied: pyOpenSSL>=23.0.0 in c:\users\dhanu\anaconda3\lib\site-packages (from sigstore->model-signing->kagglehub) (25.0.0)
# Requirement already satisfied: rich~=13.0 in c:\users\dhanu\anaconda3\lib\site-packages (from sigstore->model-signing->kagglehub) (13.3.5)
# Requirement already satisfied: rfc8785~=0.1.2 in c:\users\dhanu\anaconda3\lib\site-packages (from sigstore->model-signing->kagglehub) (0.1.4)
# Requirement already satisfied: rfc3161-client~=0.1.2 in c:\users\dhanu\anaconda3\lib\site-packages (from sigstore->model-signing->kagglehub) (0.1.2)
# Requirement already satisfied: sigstore-protobuf-specs==0.3.2 in c:\users\dhanu\anaconda3\lib\site-packages (from sigstore->model-signing->kagglehub) (0.3.2)
# Requirement already satisfied: sigstore-rekor-types==0.0.18 in c:\users\dhanu\anaconda3\lib\site-packages (from sigstore->model-signing->kagglehub) (0.0.18)
# Requirement already satisfied: tuf~=5.0 in c:\users\dhanu\anaconda3\lib\site-packages (from sigstore->model-signing->kagglehub) (5.1.0)
# Requirement already satisfied: platformdirs~=4.2 in c:\users\dhanu\anaconda3\lib\site-packages (from sigstore->model-signing->kagglehub) (4.3.6)
# Requirement already satisfied: betterproto==2.0.0b6 in c:\users\dhanu\anaconda3\lib\site-packages (from sigstore-protobuf-specs==0.3.2->sigstore->model-signing->kagglehub) (2.0.0b6)
# Requirement already satisfied: grpclib<0.5.0,>=0.4.1 in c:\users\dhanu\anaconda3\lib\site-packages (from betterproto==2.0.0b6->sigstore-protobuf-specs==0.3.2->sigstore->model-signing->kagglehub) (0.4.7)
# Requirement already satisfied: python-dateutil<3.0,>=2.8 in c:\users\dhanu\anaconda3\lib\site-packages (from betterproto==2.0.0b6->sigstore-protobuf-specs==0.3.2->sigstore->model-signing->kagglehub) (2.9.0.post0)
# Requirement already satisfied: pycparser in c:\users\dhanu\anaconda3\lib\site-packages (from cffi>=1.12->cryptography->model-signing->kagglehub) (2.21)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\dhanu\anaconda3\lib\site-packages (from pydantic<3,>=2->sigstore->model-signing->kagglehub) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\dhanu\anaconda3\lib\site-packages (from pydantic<3,>=2->sigstore->model-signing->kagglehub) (2.14.6)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\dhanu\anaconda3\lib\site-packages (from rich~=13.0->sigstore->model-signing->kagglehub) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dhanu\anaconda3\lib\site-packages (from rich~=13.0->sigstore->model-signing->kagglehub) (2.15.1)
# Requirement already satisfied: securesystemslib~=1.0 in c:\users\dhanu\anaconda3\lib\site-packages (from tuf~=5.0->sigstore->model-signing->kagglehub) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dhanu\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich~=13.0->sigstore->model-signing->kagglehub) (0.1.0)
# Requirement already satisfied: email-validator>=2.0.0 in c:\users\dhanu\anaconda3\lib\site-packages (from pydantic[email]<3,>=2->sigstore-rekor-types==0.0.18->sigstore->model-signing->kagglehub) (2.2.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\dhanu\anaconda3\lib\site-packages (from email-validator>=2.0.0->pydantic[email]<3,>=2->sigstore-rekor-types==0.0.18->sigstore->model-signing->kagglehub) (2.7.0)
# Requirement already satisfied: h2<5,>=3.1.0 in c:\users\dhanu\anaconda3\lib\site-packages (from grpclib<0.5.0,>=0.4.1->betterproto==2.0.0b6->sigstore-protobuf-specs==0.3.2->sigstore->model-signing->kagglehub) (4.2.0)
# Requirement already satisfied: multidict in c:\users\dhanu\anaconda3\lib\site-packages (from grpclib<0.5.0,>=0.4.1->betterproto==2.0.0b6->sigstore-protobuf-specs==0.3.2->sigstore->model-signing->kagglehub) (6.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\dhanu\anaconda3\lib\site-packages (from python-dateutil<3.0,>=2.8->betterproto==2.0.0b6->sigstore-protobuf-specs==0.3.2->sigstore->model-signing->kagglehub) (1.16.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\dhanu\anaconda3\lib\site-packages (from h2<5,>=3.1.0->grpclib<0.5.0,>=0.4.1->betterproto==2.0.0b6->sigstore-protobuf-specs==0.3.2->sigstore->model-signing->kagglehub) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\dhanu\anaconda3\lib\site-packages (from h2<5,>=3.1.0->grpclib<0.5.0,>=0.4.1->betterproto==2.0.0b6->sigstore-protobuf-specs==0.3.2->sigstore->model-signing->kagglehub) (4.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import kagglehub
path = kagglehub.dataset_download("abhi8923shriv/sentiment-analysis-dataset")
try:
       df = pd.read_csv(path+'/train.csv', encoding='utf-8')
except UnicodeDecodeError:
       df = pd.read_csv(path+'/train.csv', encoding='latin-1')
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.7), please consider upgrading to the latest version (0.3.8).

# %%
df.columns
# Out:
# Index(['textID', 'text', 'selected_text', 'sentiment', 'Time of Tweet',
#        'Age of User', 'Country', 'Population -2020', 'Land Area (Km²)',
#        'Density (P/Km²)'],
#       dtype='object')

# %%
def analyze_sentiment_file(text):
    # Convert the input to string before processing
    text = str(text)
    analysis = TextBlob(text)
    # Classify sentiment as positive, negative, or neutral
    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'negative'

# %%
df['sentiment'] = df['text'].apply(analyze_sentiment_file)  # Assuming your feedback column is named 'feedback'

# %%
print(df[['text', 'sentiment']].head(20))  # Print the relevant columns
# df.to_excel('output_file.xlsx', index=False)  # Save results to a new Excel file (optional)
# Out:
#                                                  text sentiment
# 0                 I`d have responded, if I were going   neutral
# 1       Sooo SAD I will miss you here in San Diego!!!  negative
# 2                           my boss is bullying me...   neutral
# 3                      what interview! leave me alone   neutral
# 4    Sons of ****, why couldn`t they put them on t...   neutral
# 5   http://www.dothebouncy.com/smf - some shameles...  positive
# 6   2am feedings for the baby are fun when he is a...  positive
# 7                                          Soooo high  positive
# 8                                         Both of you   neutral
# 9    Journey!? Wow... u just became cooler.  hehe....  positive
# 10   as much as i love to be hopeful, i reckon the...  positive
# 11  I really really like the song Love Story by Ta...  positive
# 12       My Sharpie is running DANGERously low on ink   neutral
# 13  i want to go to music tonight but i lost my vo...   neutral
# 14                         test test from the LG enV2   neutral
# 15                              Uh oh, I am sunburned   neutral
# 16   S`ok, trying to plot alternatives as we speak...   neutral
# 17  i`ve been sick for the past few days  and thus...  negative
# 18         is back home now      gonna miss every one   neutral
# 19                         Hes just not that into you   neutral

# %% [markdown]
# # Lets Begin with Senti Analysis on one of the Twitter's Dataset

# %% [markdown]
# Credits: Kaggle Open Dataset

# %% [markdown]
# 1. Handle Missing Values

# %%
# Checking for missing values
print(df.isnull().sum())
# Out:
# textID              0
# text                1
# selected_text       1
# sentiment           0
# Time of Tweet       0
# Age of User         0
# Country             0
# Population -2020    0
# Land Area (Km²)     0
# Density (P/Km²)     0
# dtype: int64

# %%
# Dropping rows with missing values
df.dropna(inplace=True)

# Alternatively, you can fill missing values with a specific value
# df.fillna("missing", inplace=True)

# %% [markdown]
# Now lets Cleanz the values, this handles the tags, URLs and Stopping Words("the, is, in")

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

# Function to clean text
def clean_text(text):
    text = re.sub(r'<.*?>', '', text)  # Remove HTML tags
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)  # Remove URLs
    text = re.sub(r'\@\w+|\#', '', text)  # Remove mentions and hashtags
    text = re.sub(r'[^A-Za-z0-9\s]', '', text)  # Remove special characters
    text = text.lower()  # Convert to lowercase
    text = text.split()
    text = [word for word in text if not word in set(stopwords.words('english'))]  # Remove stopwords
    text = ' '.join(text)
    return text

# Apply the clean_text function to the DataFrame
df['cleaned_text'] = df['text'].apply(clean_text)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dhanu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(df[['text','cleaned_text']].head(20))  # Print the relevant columns
# df.to_excel('output_file.xlsx', index=False)  # Save results to a new Excel file (optional)
# Out:
#                                                  text  \
# 0                 I`d have responded, if I were going
# 1       Sooo SAD I will miss you here in San Diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4    Sons of ****, why couldn`t they put them on t...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          Soooo high
# 8                                         Both of you
# 9    Journey!? Wow... u just became cooler.  hehe....
# 10   as much as i love to be hopeful, i reckon the...
# 11  I really really like the song Love Story by Ta...
# 12       My Sharpie is running DANGERously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the LG enV2
# 15                              Uh oh, I am sunburned
# 16   S`ok, trying to plot alternatives as we speak...
# 17  i`ve been sick for the past few days  and thus...
# 18         is back home now      gonna miss every one
# 19                         Hes just not that into you
#
#                                          cleaned_text
# 0                                  id responded going
# 1                             sooo sad miss san diego
# 2                                       boss bullying
# 3                               interview leave alone
# 4            sons couldnt put releases already bought
# 5         shameless plugging best rangers forum earth
# 6                   2am feedings baby fun smiles coos
# 7                                          soooo high
# 8
# 9           journey wow u became cooler hehe possible
# 10  much love hopeful reckon chances minimal p im ...
# 11    really really like song love story taylor swift
# 12                sharpie running dangerously low ink
# 13                   want go music tonight lost voice
# 14                                  test test lg env2
# 15                                    uh oh sunburned
# 16            sok trying plot alternatives speak sigh
# 17  ive sick past days thus hair looks wierd didnt...
# 18                     back home gonna miss every one
# 19                                                hes

# %% [markdown]
# Stemming/Lemmatization
#
# Stemming reduces words to their base or root form. For example:
#
# "running" -> "run" |
# "runner" -> "run" |
# "runs" -> "run"
#
# Lemmatization reduces words to their root form, but it considers the context and transforms words into their meaningful base forms. For example:
#
# "running" -> "run" |
# "better" -> "good"

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
nltk.download('wordnet')

# Initialize stemmer and lemmatizer
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# Function to stem/lemmatize text
def stem_lemmatize_text(text):
    text = text.split()
    text = [stemmer.stem(word) for word in text]  # Stemming
    text = [lemmatizer.lemmatize(word) for word in text]  # Lemmatization
    text = ' '.join(text)
    return text

# Apply the stem_lemmatize_text function to the cleaned text
df['processed_text'] = df['cleaned_text'].apply(stem_lemmatize_text)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\dhanu\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
print(df[['cleaned_text','processed_text']].head(20))  # Print the relevant columns
# df.to_excel('output_file.xlsx', index=False)  # Save results to a new Excel file (optional)
# Out:
#                                          cleaned_text  \
# 0                                  id responded going
# 1                             sooo sad miss san diego
# 2                                       boss bullying
# 3                               interview leave alone
# 4            sons couldnt put releases already bought
# 5         shameless plugging best rangers forum earth
# 6                   2am feedings baby fun smiles coos
# 7                                          soooo high
# 8
# 9           journey wow u became cooler hehe possible
# 10  much love hopeful reckon chances minimal p im ...
# 11    really really like song love story taylor swift
# 12                sharpie running dangerously low ink
# 13                   want go music tonight lost voice
# 14                                  test test lg env2
# 15                                    uh oh sunburned
# 16            sok trying plot alternatives speak sigh
# 17  ive sick past days thus hair looks wierd didnt...
# 18                     back home gonna miss every one
# 19                                                hes
#
#                                        processed_text
# 0                                       id respond go
# 1                             sooo sad miss san diego
# 2                                           bos bulli
# 3                                 interview leav alon
# 4               son couldnt put releas alreadi bought
# 5              shameless plug best ranger forum earth
# 6                         2am feed babi fun smile coo
# 7                                          soooo high
# 8
# 9             journey wow u becam cooler hehe possibl
# 10  much love hope reckon chanc minim p im never g...
# 11    realli realli like song love stori taylor swift
# 12                          sharpi run danger low ink
# 13                    want go music tonight lost voic
# 14                                  test test lg env2
# 15                                      uh oh sunburn
# 16                     sok tri plot altern speak sigh
# 17  ive sick past day thu hair look wierd didnt ha...
# 18                     back home gonna miss everi one
# 19                                                 he

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Word count distribution
df['word_count'] = df['processed_text'].apply(lambda x: len(x.split()))
print(df['word_count'].describe())

# Sentence length distribution
df['sentence_length'] = df['processed_text'].apply(lambda x: len(x))
print(df['sentence_length'].describe())
# Out:
# count    27480.000000
# mean         7.304803
# std          3.961223
# min          0.000000
# 25%          4.000000
# 50%          7.000000
# 75%         10.000000
# max         25.000000
# Name: word_count, dtype: float64
# count    27480.000000
# mean        39.598362
# std         21.921187
# min          0.000000
# 25%         22.000000
# 50%         37.000000
# 75%         56.000000
# max        127.000000
# Name: sentence_length, dtype: float64

# %% [markdown]
# This provides summary statistics for the word count in your dataset:
#
# count: The number of text entries in your dataset.
#
# mean: The average number of words per text entry.
#
# std: The standard deviation, which tells you how much the word counts vary from the mean.
#
# min: The minimum word count in your dataset.
#
# 25% (1st quartile): The word count at the 25th percentile.
#
# 50% (median): The word count at the 50th percentile (middle value).
#
# 75% (3rd quartile): The word count at the 75th percentile.
#
# max: The maximum word count in your dataset.

# %% [markdown]
# This provides summary statistics for the sentence length in your dataset:
#
# count: The number of text entries in your dataset.
#
# mean: The average number of characters per text entry.
#
# std: The standard deviation, which tells you how much the sentence lengths vary from the mean.
#
# min: The minimum sentence length in your dataset.
#
# 25% (1st quartile): The sentence length at the 25th percentile.
#
# 50% (median): The sentence length at the 50th percentile (middle value).
#
# 75% (3rd quartile): The sentence length at the 75th percentile.
#
# max: The maximum sentence length in your dataset.

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\dhanu\anaconda3\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\dhanu\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\dhanu\anaconda3\lib\site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in c:\users\dhanu\anaconda3\lib\site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dhanu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dhanu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dhanu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dhanu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dhanu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dhanu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dhanu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dhanu\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(df['processed_text']))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# Bar chart for sentiment class frequency
df['sentiment'].value_counts().plot(kind='bar')
plt.title('Sentiment Class Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 3. Feature Engineering

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize Count Vectorizer
count_vectorizer = CountVectorizer(max_features=5000)

# Fit and transform the processed text
X = count_vectorizer.fit_transform(df['processed_text'])

# Check the shape of the resulting matrix
print(X.shape)
# Out:
# (27480, 5000)

# %% [markdown]
# CountVectorizer is a powerful tool provided by the scikit-learn library in Python for converting a collection of text documents into a matrix of token counts.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, df['sentiment'], test_size=0.2, random_state=42)

# Initialize Logistic Regression model
model = LogisticRegression(max_iter=1000)

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Classification Report:\n{report}")
print(f"Confusion Matrix:\n{conf_matrix}")
# Out:
# Accuracy: 0.8624454148471615
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.69      0.76      1114
#      neutral       0.84      0.92      0.88      1882
#     positive       0.89      0.89      0.89      2500
#
#     accuracy                           0.86      5496
#    macro avg       0.86      0.84      0.84      5496
# weighted avg       0.86      0.86      0.86      5496
#
# Confusion Matrix:
# [[ 774  177  163]
#  [  49 1732  101]
#  [ 102  164 2234]]

# %% [markdown]
# ### Save the Model

# %%
import pickle

# Save the model to a file
with open('sentiment_model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
import pickle

# Load the model from the file
with open('sentiment_model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# %%
# Example new text data
new_texts = ["I was really looking forward to this event, but after attending, I found it to be an utter disappointment due to the poor organization, rude staff, and lack of promised activities, although I met some wonderful people."]

# Transform the new text data using the same Count Vectorizer
new_texts_transformed = count_vectorizer.transform(new_texts)

# Predict sentiments
new_predictions = loaded_model.predict(new_texts_transformed)

print(new_predictions)
# Out:
# ['negative']

# %% [markdown]
# ## Yes, we are Done with it
